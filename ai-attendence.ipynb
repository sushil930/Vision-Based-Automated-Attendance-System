# %%
pip install insightface opencv-python numpy onnxruntime
# Out:
# ...
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached scikit_image-0.26.0-cp313-cp313-win_amd64.whl.metadata (15 kB)
# ...
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# ...
#   Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached lazy_loader-0.5-py3-none-any.whl.metadata (5.9 kB)
# ...
#    ---------------------------------------- 0.0/762.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/762.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/762.2 kB ? eta -:--:--
#    ------------- -------------------------- 262.1/762.2 kB ? eta -:--:--
#    -------------------------- ----------- 524.3/762.2 kB 728.2 kB/s eta 0:00:01
#    -------------------------- ----------- 524.3/762.2 kB 728.2 kB/s eta 0:00:01
#    -------------------------------------- 762.2/762.2 kB 775.7 kB/s eta 0:00:00
# ...

# %%
from pathlib import Path

enrollment = Path("data") / "enrollment"
enrollment.mkdir(parents=True, exist_ok=True)

# %%
# !python scripts/create_gallery.py
# Out:
# Loading InsightFace...
# download_path: C:\Users\sushi/.insightface\models\buffalo_l
# ...
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\sushi/.insightface\models\buffalo_l\1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\sushi/.insightface\models\buffalo_l\2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\sushi/.insightface\models\buffalo_l\det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\sushi/.insightface\models\buffalo_l\genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# ...

# %%
# !python scripts/recognize.py
# Out:
# Loading model...
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\sushi/.insightface\models\buffalo_l\1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\sushi/.insightface\models\buffalo_l\2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\sushi/.insightface\models\buffalo_l\det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\sushi/.insightface\models\buffalo_l\genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# ...
